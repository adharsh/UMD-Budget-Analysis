# %% [markdown]
# # Tuition and Fees from 2010 - 2020

# %% [markdown]
# As shown on http://otcads.umd.edu/bfa/budgetinfo3.htm, there is a historical tuition and fees page (shown here: http://otcads.umd.edu/bfa/FY20%20Working%20Budget/web/TuitHist%202010%20to%202020%20(Excel).htm).
# This dataset has tuition rates for all kinds of students from 2010 to 2020.

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import pickle

# %% [markdown]
# ## Scraping

# %%
url = 'http://otcads.umd.edu/bfa/FY20%20Working%20Budget/web/TuitHist%202010%20to%202020%20(Excel)_files/sheet001.htm'
r = requests.get(url)

# %%
soup = BeautifulSoup(r.text,'html.parser')

# %%
# Extracting the only table there is.
len(soup.find_all('table'))
# Out:
# 1

# %%
table = soup.find('table')

# %%
str_table = []
for e in table.find_all('td'):
    if(e.text.strip()):
        str_table.append(e.text.strip())

# %% [markdown]
# In order to find the parts of the text that is necessary to copy into the dataframe, keywords like 'Undergrad Resident' were used to find the starting and ending indexes. The code directly below can be uncommented to show all the indexes of the parsed text.

# %% [raw]
# str_table
# for i in range(0, len(str_table)):
#     print(i, " ", str_table[i])

# %% [markdown]
# ## Parsing

# %%
tuition_fees = pd.DataFrame(columns=['Fee Type (Total for Fall and Spring)', 'Student Type'] + list(map(str, range(2010, 2021))))

i = str_table.index('Undergrad Resident')
while(i <= str_table.index('Mandatory Fees') - 1):
    descr = str_table[i]
    skip = 0
    if(str_table[i + 12] == '(fee per credit hour)'):
        descr = descr + ' (fee per credit hour)'
        skip = 1
        
    years = list(map(str, range(2010, 2021)))
    values = str_table[i+1:i+12]
    dictionary = dict(zip(years, values))
    dictionary['Student Type'] = descr
    
    dictionary['Fee Type (Total for Fall and Spring)'] = 'Standard Tuition Rates'
    
    tuition_fees = tuition_fees.append(dictionary, ignore_index=True)
    i = i + 12 + skip 
    
i = str_table.index('Undergrad FT')
while(i <= len(str_table) - 2):
    descr = str_table[i]
    
    years = list(map(str, range(2010, 2021)))
    values = str_table[i+1:i+12]
    dictionary = dict(zip(years, values))
    dictionary['Student Type'] = descr
    
    dictionary['Fee Type (Total for Fall and Spring)'] = 'Mandatory Fees'
    
    tuition_fees = tuition_fees.append(dictionary, ignore_index=True)
    i = i + 12

# %% [markdown]
# ## Finalizing & Fine-tuning

# %% [markdown]
# The data is now being correctly type casted.

# %%
for year in list(range(2010, 2021)):
    tuition_fees[str(year)] = tuition_fees[str(year)].apply(lambda x : x.replace(',', ''))
    tuition_fees[str(year)] = tuition_fees[str(year)].astype(float)

# %%
tuition_fees['Student Type'] = tuition_fees['Student Type'].apply(lambda x : x
                                                                  .replace('FT', 'Full-Time')
                                                                  .replace('PT', 'Part-Time')
                                                                  .replace('Non-Res', 'Non-Resident'))

# %%
tuition_fees
# Out:
#   Fee Type (Total for Fall and Spring)  \
# 0               Standard Tuition Rates
# 1               Standard Tuition Rates
# 2               Standard Tuition Rates
# 3               Standard Tuition Rates
# 4               Standard Tuition Rates
# 5               Standard Tuition Rates
# 6                       Mandatory Fees
# 7                       Mandatory Fees
# 8                       Mandatory Fees
# 9                       Mandatory Fees
#
#                                         Student Type     2010     2011  \
# 0                                 Undergrad Resident   6566.0   6763.0
# 1                             Undergrad Non-Resident  22503.0  23178.0
# 2  Undergrad Part-Time Resident (fee per credit h...    273.0    282.0
# 3  Undergrad Part-Time Non-Resident (fee per cred...    938.0    966.0
# 4            Graduate Resident (fee per credit hour)    471.0    500.0
# 5        Graduate Non-Resident (fee per credit hour)   1016.0   1077.0
# 6                                Undergrad Full-Time   1487.0   1653.0
# 7                                Undergrad Part-Time    678.0    761.0
# 8                                 Graduate Full-Time   1188.0   1351.0
# 9                                 Graduate Part-Time    675.0    757.0
#
#       2012     2013     2014     2015     2016     2017     2018     2019  \
# 0   6966.0   7175.0   7390.0   7764.0   8152.0   8315.0   8481.0   8651.0
# 1  24337.0  25554.0  26576.0  27905.0  29300.0  30179.0  31688.0  33272.0
# 2    290.0    299.0    308.0    324.0    340.0    346.0    353.0    360.0
# 3   1014.0   1065.0   1108.0   1163.0   1221.0   1258.0   1321.0   1387.0
# 4    525.0    551.0    573.0    602.0    632.0    651.0    683.0    717.0
# 5   1131.0   1188.0   1236.0   1298.0   1363.0   1404.0   1474.0   1548.0
# 6   1689.0   1733.0   1771.0   1815.0   1844.0   1866.0   1918.0   1944.0
# 7    779.0    799.0    818.0    840.0    855.0    866.0    893.0    906.0
# 8   1383.0   1413.0   1446.0   1490.0   1521.0   1538.0   1590.0   1620.0
# 9    773.0    788.0    806.0    829.0    846.0    855.0    881.0    898.0
#
#       2020
# 0   8824.0
# 1  34936.0
# 2    367.0
# 3   1456.0
# 4    731.0
# 5   1625.0
# 6   1955.0
# 7    910.0
# 8   1635.0
# 9    902.0

# %% [markdown]
# # Transpose
#
# The transpose will be taken to make 'Year' into one column to make plots easier. This will also make each column a timeseries, which is much easier to handle.

# %%
tuition_fees = tuition_fees.transpose()
tuition_fees.head()
# Out:
#                                                            0  \
# Fee Type (Total for Fall and Spring)  Standard Tuition Rates
# Student Type                              Undergrad Resident
# 2010                                                    6566
# 2011                                                    6763
# 2012                                                    6966
#
#                                                            1  \
# Fee Type (Total for Fall and Spring)  Standard Tuition Rates
# Student Type                          Undergrad Non-Resident
# 2010                                                   22503
# 2011                                                   23178
# 2012                                                   24337
#
#                                                                                       2  \
# Fee Type (Total for Fall and Spring)                             Standard Tuition Rates
# Student Type                          Undergrad Part-Time Resident (fee per credit h...
# 2010                                                                                273
# 2011                                                                                282
# 2012                                                                                290
#
#                                                                                       3  \
# Fee Type (Total for Fall and Spring)                             Standard Tuition Rates
# Student Type                          Undergrad Part-Time Non-Resident (fee per cred...
# 2010                                                                                938
# 2011                                                                                966
# 2012                                                                               1014
#
#                                                                             4  \
# Fee Type (Total for Fall and Spring)                   Standard Tuition Rates
# Student Type                          Graduate Resident (fee per credit hour)
# 2010                                                                      471
# 2011                                                                      500
# 2012                                                                      525
#
#                                                                                 5  \
# Fee Type (Total for Fall and Spring)                       Standard Tuition Rates
# Student Type                          Graduate Non-Resident (fee per credit hour)
# 2010                                                                         1016
# 2011                                                                         1077
# 2012                                                                         1131
#
#                                                         6  \
# Fee Type (Total for Fall and Spring)       Mandatory Fees
# Student Type                          Undergrad Full-Time
# 2010                                                 1487
# 2011                                                 1653
# 2012                                                 1689
#
#                                                         7                   8  \
# Fee Type (Total for Fall and Spring)       Mandatory Fees      Mandatory Fees
# Student Type                          Undergrad Part-Time  Graduate Full-Time
# 2010                                                  678                1188
# 2011                                                  761                1351
# 2012                                                  779                1383
#
#                                                        9
# Fee Type (Total for Fall and Spring)      Mandatory Fees
# Student Type                          Graduate Part-Time
# 2010                                                 675
# 2011                                                 757
# 2012                                                 773

# %%
list1 = list(tuition_fees.iloc[0].values)
list2 = list(tuition_fees.iloc[1].values)
new_columns = ([str(a) + b for a,b in zip(list(map(lambda x : x + ": ", list1)),list2)])
tuition_fees.columns = new_columns

# %%
tuition_fees = tuition_fees.drop(['Fee Type (Total for Fall and Spring)', 'Student Type'])
tuition_fees = tuition_fees.reset_index()
tuition_fees = tuition_fees.rename(columns={'index' : 'Year'})

# %%
tuition_fees
# Out:
#     Year Standard Tuition Rates: Undergrad Resident  \
# 0   2010                                       6566
# 1   2011                                       6763
# 2   2012                                       6966
# 3   2013                                       7175
# 4   2014                                       7390
# 5   2015                                       7764
# 6   2016                                       8152
# 7   2017                                       8315
# 8   2018                                       8481
# 9   2019                                       8651
# 10  2020                                       8824
#
#    Standard Tuition Rates: Undergrad Non-Resident  \
# 0                                           22503
# 1                                           23178
# 2                                           24337
# 3                                           25554
# 4                                           26576
# 5                                           27905
# 6                                           29300
# 7                                           30179
# 8                                           31688
# 9                                           33272
# 10                                          34936
#
#    Standard Tuition Rates: Undergrad Part-Time Resident (fee per credit hour)  \
# 0                                                 273
# 1                                                 282
# 2                                                 290
# 3                                                 299
# 4                                                 308
# 5                                                 324
# 6                                                 340
# 7                                                 346
# 8                                                 353
# 9                                                 360
# 10                                                367
#
#    Standard Tuition Rates: Undergrad Part-Time Non-Resident (fee per credit hour)  \
# 0                                                 938
# 1                                                 966
# 2                                                1014
# 3                                                1065
# 4                                                1108
# 5                                                1163
# 6                                                1221
# 7                                                1258
# 8                                                1321
# 9                                                1387
# 10                                               1456
#
#    Standard Tuition Rates: Graduate Resident (fee per credit hour)  \
# 0                                                 471
# 1                                                 500
# 2                                                 525
# 3                                                 551
# 4                                                 573
# 5                                                 602
# 6                                                 632
# 7                                                 651
# 8                                                 683
# 9                                                 717
# 10                                                731
#
#    Standard Tuition Rates: Graduate Non-Resident (fee per credit hour)  \
# 0                                                1016
# 1                                                1077
# 2                                                1131
# 3                                                1188
# 4                                                1236
# 5                                                1298
# 6                                                1363
# 7                                                1404
# 8                                                1474
# 9                                                1548
# 10                                               1625
#
#    Mandatory Fees: Undergrad Full-Time Mandatory Fees: Undergrad Part-Time  \
# 0                                 1487                                 678
# 1                                 1653                                 761
# 2                                 1689                                 779
# 3                                 1733                                 799
# 4                                 1771                                 818
# 5                                 1815                                 840
# 6                                 1844                                 855
# 7                                 1866                                 866
# 8                                 1918                                 893
# 9                                 1944                                 906
# 10                                1955                                 910
#
#    Mandatory Fees: Graduate Full-Time Mandatory Fees: Graduate Part-Time
# 0                                1188                                675
# 1                                1351                                757
# 2                                1383                                773
# 3                                1413                                788
# 4                                1446                                806
# 5                                1490                                829
# 6                                1521                                846
# 7                                1538                                855
# 8                                1590                                881
# 9                                1620                                898
# 10                               1635                                902

# %%
tuition_fees.to_pickle('df/tuition_fees')
